# %% [markdown]
# #### **Import Libraries**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt

# %% [markdown]
# #### **Defining Image_size,Batch_size and Epochs**

# %%
IMAGE_SIZE=144
BATCH_SIZE=20
EPOCHS=50
CHANNELS=3
EPOCHS=50

# %% [markdown]
# #### **Reading the train dataset**

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory(
    "Dataset/train",
    shuffle=True,
    seed=123,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    # color_mode='grayscale'
)
# Out:
# Found 11879 files belonging to 2 classes.

# %%
dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 144, 144, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# #### **Reading the test dataset**

# %%
test_dataset=tf.keras.preprocessing.image_dataset_from_directory(
    "Dataset/test",
    shuffle=True,
    seed=123,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 2000 files belonging to 2 classes.

# %%
class_names=dataset.class_names
class_names
# Out:
# ['Benign', 'Malignant']

# %%
len(dataset)
# Out:
# 594

# %% [markdown]
# #### **Plotting Image for two different class**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))

for image_batch, label_batch in dataset.take(1):
    if len(image_batch) < 12 or len(label_batch) < 12:
        print("Error: Batch size is smaller than 12")
        break

    for i in range(12):
        ax = plt.subplot(3, 4, i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"), cmap='gray')  # Use cmap='gray' for grayscale images
        plt.axis("off")
        plt.title(class_names[label_batch[i]])

plt.show()

# %% [markdown]
# #### **Train,validation and Test split**

# %%
def get_dataset_partitation(ds,train_split=0.8,valid_split=0.1,test_split=0.1,shuffle=True,shuffle_size=10000):
    assert(train_split+valid_split+test_split==1)
    ds_size=len(ds)
    if shuffle:
        ds=ds.shuffle(shuffle_size,seed=12)

    train_size=int(ds_size*train_split)
    test_size=int(ds_size*test_split)
    valid_size=int(ds_size*valid_split)
    train_ds=ds.take(train_size)
    valid_ds=ds.skip(train_size).take(valid_size)
    test_ds=ds.skip(train_size).skip(valid_size)

    return train_ds,valid_ds,test_ds

# %%
train_ds,valid_ds,test_ds=get_dataset_partitation(dataset)

# %%
len(train_ds)
# Out:
# 475

# %%
len(test_ds)
# Out:
# 60

# %%
len(valid_ds)
# Out:
# 59

# %% [markdown]
# #### **Optimize Image fetching**

# %%
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds=test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
valid_ds=valid_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# #### **Resize and Rescale**

# %%
resize_and_rescale=tf.keras.Sequential(
    [
        layers.Resizing(IMAGE_SIZE,IMAGE_SIZE),
        layers.Rescaling(1./255)
    ]
)

# %% [markdown]
# #### **Data Augmentation**

# %%
data_augmentation=tf.keras.Sequential(
   [ layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.3)]
)

# %% [markdown]
# #### **Model Building**

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 2

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid'),
])


model.build(input_shape=input_shape)
# Out:
# c:\Users\AnsaB\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (20, 144, 144, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (20, 144, 144, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (20, 142, 142, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (20, 71, 71, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (20, 69, 69, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (20, 34, 34, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (20, 32, 32, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (20, 65536)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (20, 64)               │     4,194,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (20, 1)                │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,250,753 (16.22 MB)
#  Trainable params: 4,250,753 (16.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=valid_ds,
    verbose=1,
    epochs=50,
)
# Out:
# Epoch 1/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 55s 106ms/step - accuracy: 0.6683 - loss: 0.6263 - val_accuracy: 0.8136 - val_loss: 0.4204
# Epoch 2/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 50s 104ms/step - accuracy: 0.8136 - loss: 0.4099 - val_accuracy: 0.8237 - val_loss: 0.3860
# Epoch 3/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 50s 104ms/step - accuracy: 0.8224 - loss: 0.3975 - val_accuracy: 0.8195 - val_loss: 0.3784
# Epoch 4/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 48s 101ms/step - accuracy: 0.8321 - loss: 0.3864 - val_accuracy: 0.8271 - val_loss: 0.3596
# Epoch 5/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 50s 106ms/step - accuracy: 0.8277 - loss: 0.3773 - val_accuracy: 0.8119 - val_loss: 0.3815
# Epoch 6/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 49s 103ms/step - accuracy: 0.8329 - loss: 0.3782 - val_accuracy: 0.8407 - val_loss: 0.3551
# Epoch 7/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 50s 106ms/step - accuracy: 0.8335 - loss: 0.3741 - val_accuracy: 0.8229 - val_loss: 0.3662
# Epoch 8/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.8368 - loss: 0.3661 - val_accuracy: 0.8441 - val_loss: 0.3663
# Epoch 9/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 47s 98ms/step - accuracy: 0.8392 - loss: 0.3637 - val_accuracy: 0.8508 - val_loss: 0.3432
# Epoch 10/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 48s 100ms/step - accuracy: 0.8383 - loss: 0.3584 - val_accuracy: 0.8263 - val_loss: 0.3462
# Epoch 11/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 46s 97ms/step - accuracy: 0.8398 - loss: 0.3543 - val_accuracy: 0.8441 - val_loss: 0.3366
# Epoch 12/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 45s 95ms/step - accuracy: 0.8485 - loss: 0.3398 - val_accuracy: 0.8458 - val_loss: 0.3342
# Epoch 13/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.8506 - loss: 0.3319 - val_accuracy: 0.8449 - val_loss: 0.3643
# Epoch 14/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 46s 97ms/step - accuracy: 0.8392 - loss: 0.3462 - val_accuracy: 0.8322 - val_loss: 0.3657
# Epoch 15/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 48s 101ms/step - accuracy: 0.8485 - loss: 0.3314 - val_accuracy: 0.8559 - val_loss: 0.3104
# Epoch 16/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 52s 109ms/step - accuracy: 0.8596 - loss: 0.3151 - val_accuracy: 0.8602 - val_loss: 0.3040
# Epoch 17/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 48s 102ms/step - accuracy: 0.8632 - loss: 0.3056 - val_accuracy: 0.8263 - val_loss: 0.3551
# Epoch 18/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 47s 99ms/step - accuracy: 0.8594 - loss: 0.3182 - val_accuracy: 0.8576 - val_loss: 0.3062
# Epoch 19/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 48s 100ms/step - accuracy: 0.8613 - loss: 0.3135 - val_accuracy: 0.8669 - val_loss: 0.2880
# Epoch 20/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 50s 105ms/step - accuracy: 0.8632 - loss: 0.3094 - val_accuracy: 0.8610 - val_loss: 0.2977
# Epoch 21/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 50s 106ms/step - accuracy: 0.8691 - loss: 0.2977 - val_accuracy: 0.8661 - val_loss: 0.2933
# Epoch 22/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 49s 104ms/step - accuracy: 0.8655 - loss: 0.3061 - val_accuracy: 0.8559 - val_loss: 0.3011
# Epoch 23/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 47s 99ms/step - accuracy: 0.8606 - loss: 0.3100 - val_accuracy: 0.8559 - val_loss: 0.3096
# Epoch 24/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 47s 98ms/step - accuracy: 0.8756 - loss: 0.2849 - val_accuracy: 0.8619 - val_loss: 0.3048
# Epoch 25/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.8771 - loss: 0.2882 - val_accuracy: 0.8797 - val_loss: 0.2735
# Epoch 26/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 49s 103ms/step - accuracy: 0.8718 - loss: 0.2890 - val_accuracy: 0.8729 - val_loss: 0.2767
# Epoch 27/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 47s 99ms/step - accuracy: 0.8744 - loss: 0.2804 - val_accuracy: 0.8754 - val_loss: 0.2815
# Epoch 28/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 51s 108ms/step - accuracy: 0.8793 - loss: 0.2831 - val_accuracy: 0.8814 - val_loss: 0.2727
# Epoch 29/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 49s 104ms/step - accuracy: 0.8756 - loss: 0.2756 - val_accuracy: 0.8873 - val_loss: 0.2647
# Epoch 30/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 47s 100ms/step - accuracy: 0.8802 - loss: 0.2765 - val_accuracy: 0.8771 - val_loss: 0.2638
# Epoch 31/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 48s 101ms/step - accuracy: 0.8755 - loss: 0.2763 - val_accuracy: 0.8729 - val_loss: 0.2666
# Epoch 32/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 47s 98ms/step - accuracy: 0.8774 - loss: 0.2776 - val_accuracy: 0.8703 - val_loss: 0.2904
# Epoch 33/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 46s 97ms/step - accuracy: 0.8858 - loss: 0.2617 - val_accuracy: 0.8729 - val_loss: 0.2654
# Epoch 34/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 45s 95ms/step - accuracy: 0.8807 - loss: 0.2667 - val_accuracy: 0.8864 - val_loss: 0.2581
# Epoch 35/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 46s 98ms/step - accuracy: 0.8932 - loss: 0.2561 - val_accuracy: 0.8847 - val_loss: 0.2607
# Epoch 36/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 47s 98ms/step - accuracy: 0.8848 - loss: 0.2631 - val_accuracy: 0.8797 - val_loss: 0.2645
# Epoch 37/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 48s 102ms/step - accuracy: 0.8827 - loss: 0.2575 - val_accuracy: 0.8737 - val_loss: 0.2547
# Epoch 38/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 49s 104ms/step - accuracy: 0.8930 - loss: 0.2552 - val_accuracy: 0.8805 - val_loss: 0.2778
# Epoch 39/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 46s 97ms/step - accuracy: 0.8856 - loss: 0.2595 - val_accuracy: 0.8780 - val_loss: 0.2645
# Epoch 40/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 46s 96ms/step - accuracy: 0.8837 - loss: 0.2573 - val_accuracy: 0.8831 - val_loss: 0.2433
# Epoch 41/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 46s 96ms/step - accuracy: 0.8855 - loss: 0.2634 - val_accuracy: 0.8847 - val_loss: 0.2573
# Epoch 42/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 46s 96ms/step - accuracy: 0.8880 - loss: 0.2575 - val_accuracy: 0.8729 - val_loss: 0.2709
# Epoch 43/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 46s 96ms/step - accuracy: 0.8924 - loss: 0.2493 - val_accuracy: 0.8864 - val_loss: 0.2459
# Epoch 44/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 46s 97ms/step - accuracy: 0.8881 - loss: 0.2562 - val_accuracy: 0.8856 - val_loss: 0.2589
# Epoch 45/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 46s 96ms/step - accuracy: 0.8886 - loss: 0.2469 - val_accuracy: 0.8966 - val_loss: 0.2508
# Epoch 46/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.8878 - loss: 0.2482 - val_accuracy: 0.8890 - val_loss: 0.2368
# Epoch 47/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.8916 - loss: 0.2495 - val_accuracy: 0.8907 - val_loss: 0.2403
# Epoch 48/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.9003 - loss: 0.2334 - val_accuracy: 0.9017 - val_loss: 0.2345
# Epoch 49/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.8977 - loss: 0.2403 - val_accuracy: 0.8932 - val_loss: 0.2454
# Epoch 50/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 45s 96ms/step - accuracy: 0.9003 - loss: 0.2320 - val_accuracy: 0.8941 - val_loss: 0.2560

# %% [markdown]
# #### **Model Accuracy Plot**

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'],color='red',label='train_loss')
plt.plot(history.history['val_loss'],color='blue',label='validation_loss')
plt.legend()
plt.show()

# %% [markdown]
# #### **Testing of train model**

# %%
scores=model.evaluate(test_ds)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8925 - loss: 0.2525

# %% [markdown]
# #### **Test dataset Accuracy**

# %%
scores_test=model.evaluate(test_dataset)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9030 - loss: 0.2618

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image,cmap='gray')
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Benign
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# predicted label: Benign

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(20, 20))
for images, labels in test_ds.take(1):
    for i in range(12):
        ax = plt.subplot(4, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"),cmap='gray')

        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %% [markdown]
# #### **Actual vs Predict Image**

# %%
plt.figure(figsize=(20, 20))
for images, labels in test_dataset.take(10):
    for i in range(12):
        ax = plt.subplot(4, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %% [markdown]
# #### **Saving Model**

# %%
# Save the trained model to disk using TensorFlow's built-in method
model.save('trained_model.keras')
